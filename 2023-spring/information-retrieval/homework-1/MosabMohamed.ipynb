# %% [markdown]
# # 1. Crawler
#
# ## 1.0. Related example
#
# This code shows `wget`-like tool written in python. Run it from console (`python wget.py`), make it work. Check the code, reuse, and modify for your needs.

# %%
import argparse
import os
import re
import requests


def wget(url, filename):
    # allow redirects - in case file is relocated
    resp = requests.get(url, allow_redirects=True)
    # this can also be 2xx, but for simplicity now we stick to 200
    # you can also check for `resp.ok`
    if resp.status_code != 200:
        print(resp.status_code, resp.reason, 'for', url)
        return
    
    # just to be cool and print something
    print(*[f"{key}: {value}" for key, value in resp.headers.items()], sep='\n')
    print()
    
    # try to extract filename from url
    if filename is None:
        # start with http*, ends if ? or # appears (or none of)
        m = re.search("^http.*/([^/\?#]*)[\?#]?", url)
        filename = m.group(1)
        if not filename:
            raise NameError(f"Filename neither given, nor found for {url}")

    # what will you do in case 2 websites store file with the same name?
    if os.path.exists(filename):
        raise OSError(f"File {filename} already exists")
    
    with open(filename, 'wb') as f:
        f.write(resp.content)
        print(f"File saved as {filename}")


if __name__ == "__main__":
    parser = argparse.ArgumentParser(description='download file.')
    parser.add_argument("-O", type=str, default=None, dest='filename', help="output file name. Default -- taken from resource")
    parser.add_argument("url", type=str, default=None, help="Provide URL here")
    args = parser.parse_args()
    wget(args.url, args.filename)
# Out:
# usage: ipykernel_launcher.py [-h] [-O FILENAME] url
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %% [markdown]
# ### 1.0.1. How to parse a page?
#
# If you build a crawler, you might follow one of the approaches:
# 1. search for URLs in the page, assuming this is just a text.
# 2. search for URLs in the places where URLs should appear: `<a href=..`, `<img src=...`, `<iframe src=...` and so on.
#
# To follow the first approach you can rely on some good regular expression. [Like this](https://stackoverflow.com/a/3809435).
#
# To follow the second approach just read one of these: [short answer](https://stackoverflow.com/questions/1080411/retrieve-links-from-web-page-using-python-and-beautifulsoup) or [exhaustive explanation](https://hackersandslackers.com/scraping-urls-with-beautifulsoup/).

# %% [markdown]
# ## 1.1. [15] Download and persist #
# Please complete a code for `load()`, `download()` and `persist()` methods of `Document` class. What they do:
# - for a given URL `download()` method downloads binary data and stores in `self.content`. It returns `True` for success, else `False`.
# - `persist()` method saves `self.content` somewhere in file system. We do it to avoid multiple downloads (for caching in other words).
# - `load()` method loads data from hard drive. Returns `True` for success.
#
# Tests checks that your code somehow works.
#
# **NB Passing the test doesn't mean you correctly completed the task.** These are **criteria, which have to be fullfilled**:
# 1. URL is a unique identifier (as it is a subset of URI). Thus, documents with different URLs should be stored in different files. Typical errors: documents from the same domain are overwritten to the same file, URLs with similar endings are downloaded to the same file, etc.
# 2. The document can be not only a text file, but also a binary. Pay attention that if you download `mp3` file, it still can be played. Hint: don't hurry to convert everything to text.

# %%
from urllib.parse import urlparse # for retrieving file extension from url
from hashlib import sha512 # for filename hashing
import requests

class Document:
    
    def __init__(self, url):
        self.url = url
        
        hashed_filename = sha512(url.encode()).hexdigest()
        extension = urlparse(url).path.split('.') 
        if len(extension) > 1: # if there is an extension
            self.name = f"{hashed_filename}.{extension[-1]}"
            self.ext = extension[-1]
        else: # if there is no extension treat it as html
            self.name = f"{hashed_filename}.html"
            self.ext = "html"
        
        os.makedirs("files", exist_ok=True) # create files directory if it does not exist
        
    def get(self):
        if not self.load():
            if not self.download():
                raise FileNotFoundError(self.url)
            else:
                self.persist()
    
    def download(self):
        downloaded_content = requests.get(self.url, timeout=5) # get content from url with timeout of 5 seconds to avoid spending too much time on one file
        if downloaded_content.status_code == 200: # if status code is 200 (OK)
            self.content = downloaded_content.content # save content
            return True
        return False
    
    def persist(self):
        with open(f"files/{self.name}", 'wb') as f: # open file in write binary mode
            f.write(self.content) # write content to file
        pass
            
    def load(self):
        if os.path.exists(f"files/{self.name}"): # if file exists
            with open(f"files/{self.name}", 'rb') as f: # open file in read binary mode
                self.content = f.read() # read content from file
                return True
        return False

# %% [markdown]
# ### 1.1.1. Tests ###

# %%
doc = Document('http://sprotasov.ru/data/iu.txt')

doc.get()
assert doc.content, "Document download failed"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document content error"

doc.get()
assert doc.load(), "Load should return true for saved document"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document load from disk error"

# %% [markdown]
# ## 1.2. [10] Parse HTML
# `BeautifulSoap` library is a de facto standard to parse XML and HTML documents in python. Use it to complete `parse()` method that extracts document contents. You should initialize:
# 1. `self.anchors` list of tuples `('text', 'url')` met in a document. Be aware, there exist relative links (e.g. `../content/pic.jpg`). Use `urllib.parse.urljoin()` to fix this issue.
# 2. `self.images` list of images met in a document. Again, links can be relative to current page.
# 3. `self.text` should keep plain text of the document without scripts, tags, comments and so on. You can refer to [this stackoverflow answer](https://stackoverflow.com/a/1983219) for details.
#
# **NB All these 3 criteria must be fulfilled to get full point for the task.**

# %%
from bs4 import BeautifulSoup
import urllib.parse

class HtmlDocument(Document):
    
    def parse(self):
        soup = BeautifulSoup(self.content, 'html.parser') # parse html
        self.anchors = self.parse_anchors(soup=soup) 
        self.images = self.parse_images(soup=soup)
        self.text = self.parse_text(soup=soup)
        
    def parse_anchors(self, soup):
        anchors = []
        for link in soup.find_all('a'): 
            href = link.get('href') 
            if href: 
                anchors.append((link.text, urllib.parse.urljoin(self.url, href))) # add tuple of text and url to anchors
        return anchors

    def parse_images(self, soup):
        images = []
        for image in soup.find_all('img'):
            src = image.get('src') 
            if src:
                images.append(urllib.parse.urljoin(self.url, src)) # add url to images
        return images

    def parse_text(self, soup): 
        # since we are parsing html, we can use soup.find('body') to get body which will contain all plain texts without scripts, tags, comments and so on 
        # and it will also help us later on in the document analysis
        text = soup.find('body').text.strip() # get text from body
        return text

# %% [markdown]
# ### 1.2.1. Tests

# %%
doc = HtmlDocument("http://sprotasov.ru")
doc.get()
doc.parse()

assert "just few links" in doc.text, "Error parsing text"
assert "http://sprotasov.ru/images/gb.svg" in doc.images, "Error parsing images"
assert any(p[1] == "https://twitter.com/07C3" for p in doc.anchors), "Error parsing links"

# %% [markdown]
# ## 1.3. [10] Document analysis ##
# Complete the code for `HtmlDocumentTextData` class. Implement word and sentence splitting (use any method you can propose).
#
# **Criteria to succeed in the task**:
# 1. Your `get_word_stats()` method should return `Counter` object.
# 2. Don't forget to lowercase your words for counting.
# 3. Sentences should be obtained from inside `<body>` tag only.

# %%
#references: 
# https://www.w3tweaks.com/html-file-extensions.html#jspextension
# https://fileinfo.com/filetypes/web
# https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML#What_is_HTML
# https://www.w3schools.com/whatis/whatis_html.asp

from collections import Counter

class HtmlDocumentTextData:
    # Due to the class name I assume that it is responsible for text data extraction from ONLY html documents
    # So I decided to check the extension of the document and raise an error if it is not one of the most common html extensions ('html', 'htm', 'php', 'do', 'asp', 'aspx', 'jsp', 'cfm', 'shtml', 'xhtml')
    # but since there are too many html extensions, i decided to check if the extension is not wanted ('pdf', 'mp3', 'avi', 'mp4', 'txt') instead of checking if it is wanted
    # if it is not wanted then raise an error
    def __init__(self, url):
        self.doc = HtmlDocument(url)
        if self.doc.ext in ('pdf', 'mp3', 'avi', 'mp4', 'txt'): # if extension is not an html extension
            raise ValueError("Only html documents are supported, got: " + self.doc.ext) # raise error
        self.doc.get()
        self.doc.parse()
    
    def get_sentences(self):
        # since we already parsed the text from the body in the previous part, we can just split it by line breaks
        result = self.doc.text.splitlines() # split text by lines, because sentences are usually separated by line breaks
        return result
    
    def get_word_stats(self):
        result = Counter()
        for sentence in self.get_sentences(): # for each sentence
            for word in sentence.split(): # split sentence by words
                word = word.lower() # convert word to lowercase
                while word and not word[0].isalnum(): # remove non-alphanumeric characters from the beginning of the word
                    word = word[1:]
                while word and not word[-1].isalnum(): # remove non-alphanumeric characters from the end of the word
                    word = word[:-1]
                if word == '': # if word is empty string, skip it. It happens when there are only non-alphanumeric characters in the word
                    continue
                result[word] += 1 # add word to counter
        return result

# %% [markdown]
# ### 1.3.1. Tests ###

# %%
doc = HtmlDocumentTextData("https://innopolis.university/")

print(doc.get_word_stats().most_common(10))
assert [x for x in doc.get_word_stats().most_common(10) if x[0] == 'иннополис'], 'иннополис should be among most common'
# Out:
# [('и', 42), ('в', 22), ('иннополис', 20), ('с', 13), ('на', 12), ('университет', 11), ('университета', 11), ('центр', 10), ('для', 9), ('по', 8)]

# %% [markdown]
# ## 1.4. [15] Crawling ##
#
# Method `crawl_generator()` is given starting url (`source`) and max depth of search. It should return a **generator** of `HtmlDocumentTextData` objects (return a document as soon as it is downloaded and parsed). You can benefit from `yield obj_name` python construction. Use `HtmlDocumentTextData.anchors` field to go deeper.

# %%
from queue import Queue

class Crawler:
    
    def crawl_generator(self, source, depth=1): 
        queue = Queue() # queue that will be used to store urls and their depth
        queue.put((source, 0)) 
        visited = set() # set that will be used to store visited urls
        while not queue.empty(): # while queue is not empty
            url, level = queue.get() # get url and level from queue
            if url in visited: # if url is already visited, skip it
                continue
            visited.add(url) # add url to visited set
            try: # try to get and parse document
                yield HtmlDocumentTextData(url) # yield document
                if level < depth: # if level is less than depth
                    site = HtmlDocumentTextData(url) 
                    for anchor in site.doc.anchors: # for each anchor
                        queue.put((anchor[1], level + 1)) # add url and level to queue
            except Exception as e: # if there is an error print it and continue
                print("Error processing {}: {}".format(url, e))

# %% [markdown]
# ### 1.4.1. Tests ###

# %%
crawler = Crawler()
counter = Counter()

for c in crawler.crawl_generator("https://innopolis.university/en/", 2):
    print(c.doc.url)
    if c.doc.url[-4:] in ('.pdf', '.mp3', '.avi', '.mp4', '.txt'):
        print("Skipping", c.doc.url)
        continue
    # since not all urls end with the extension i decided to make another if block to check if c.doc.ext is in the list of extensions
    # THE UPCOMING BLOCK IS ADDED BY ME
    if c.doc.ext in ('pdf', 'mp3', 'avi', 'mp4', 'txt'):
        print("Skipping", c.doc.url)
        continue
    # THE PREVIOUS BLOCK IS ADDED BY ME
    counter.update(c.get_word_stats())
    print(len(counter), "distinct word(s) so far")
    
print("Done")

print(counter.most_common(20))
assert [x for x in counter.most_common(20) if x[0] == 'innopolis'], 'innopolis sould be among most common'
# Out:
# https://innopolis.university/en/
# 334 distinct word(s) so far
# https://innopolis.university/
# 889 distinct word(s) so far
# https://apply.innopolis.university/en
# 1522 distinct word(s) so far
# Error processing https://innopolis.university/proekty/activity/en": https://innopolis.university/proekty/activity/en"
# https://media.innopolis.university/en
# 1592 distinct word(s) so far
# https://innopolis.university/lk/
# 1604 distinct word(s) so far
# https://innopolis.university/en/about/
# 1788 distinct word(s) so far
# https://innopolis.university/en/board/
# 1867 distinct word(s) so far
# https://innopolis.university/en/team/
# 1868 distinct word(s) so far
# https://innopolis.university/en/team-structure/
# 1871 distinct word(s) so far
# https://innopolis.university/en/team-structure/education-academics/
# 1872 distinct word(s) so far
# https://innopolis.university/en/team-structure/techcenters/
# 1876 distinct word(s) so far
# https://innopolis.university/en/faculty/
# 2776 distinct word(s) so far
# https://career.innopolis.university/en/job/
# 3292 distinct word(s) so far
# https://career.innopolis.university/en/
# 3416 distinct word(s) so far
# https://innopolis.university/en/campus
# 3539 distinct word(s) so far
# https://innopolis.university/en/contacts/
# 3552 distinct word(s) so far
# https://apply.innopolis.university/en/
# 3552 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/
# 3623 distinct word(s) so far
# https://apply.innopolis.university/en/master/
# 3642 distinct word(s) so far
# https://apply.innopolis.university/en/postgraduate-study/
# 3687 distinct word(s) so far
# https://apply.innopolis.university/en/stud-life/
# 3755 distinct word(s) so far
# https://innopolis.university/en/international-relations-office/
# 3993 distinct word(s) so far
# https://innopolis.university/en/incomingstudents/
# 4384 distinct word(s) so far
# https://innopolis.university/en/outgoingstudents/
# 4771 distinct word(s) so far
# https://innopolis.university/en/teachingexcellencecenter/
# 4957 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/
# 4971 distinct word(s) so far
# https://alumni.innopolis.university/
# 5147 distinct word(s) so far
# https://innopolis.university/en/research/
# 5182 distinct word(s) so far
# https://innopolis.university/en/team-structure/team-faculty/
# 5197 distinct word(s) so far
# https://innopolis.university/en/team-structure/team-faculty2/
# 5207 distinct word(s) so far
# https://innopolis.university/en/nir2022/
# 5369 distinct word(s) so far
# https://innopolis.university/en/proekty/activity/
# 5409 distinct word(s) so far
# https://innopolis.university/en/startupstudio/
# 5443 distinct word(s) so far
# https://innopolis.university/en/internationalpartners/
# 5519 distinct word(s) so far
# https://innopolis.university/en/organizatsiya-i-provedenie-meropriyatiy/
# 5612 distinct word(s) so far
# https://innopolis.university/en/?special=Y
# 5621 distinct word(s) so far
# https://innopolis.university/search/
# 5624 distinct word(s) so far
# https://innopolis.university/en/ido/
# 5651 distinct word(s) so far
# https://dovuz.innopolis.university/
# 5821 distinct word(s) so far
# Error processing https://university.innopolis.ru/en/about/: HTTPSConnectionPool(host='university.innopolis.ru', port=443): Max retries exceeded with url: /en/about/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:997)')))
# Error processing http://www.campuslife.innopolis.ru: http://www.campuslife.innopolis.ru
# https://media.innopolis.university/news/webinar-interstudents-eng/
# 5857 distinct word(s) so far
# https://media.innopolis.university/news/devops-summer-school/
# 5997 distinct word(s) so far
# https://media.innopolis.university/news/webinar-for-international-candidates-/
# 6003 distinct word(s) so far
# https://media.innopolis.university/news/registration-innopolis-open-2020/
# 6093 distinct word(s) so far
# https://media.innopolis.university/news/cyber-resilience-petrenko/
# 6258 distinct word(s) so far
# https://media.innopolis.university/news/innopolis-university-extends-international-application-deadline-/
# 6264 distinct word(s) so far
# https://media.innopolis.university/news/self-driven-school/
# 6334 distinct word(s) so far
# https://media.innopolis.university/en/
# 6334 distinct word(s) so far
# Error processing tel:+7 (843) 203-92-53: No connection adapters were found for 'tel:+7 (843) 203-92-53'
# Error processing https://innopolis.university/en/university@innopolis.ru: https://innopolis.university/en/university@innopolis.ru
# https://innopolis.university/en/form/
# 6416 distinct word(s) so far
# Error processing https://innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf: Only html documents are supported, got: pdf
# https://t.me/universityinnopolis
# 6421 distinct word(s) so far
# https://vk.com/innopolisu
# 6607 distinct word(s) so far
# https://www.youtube.com/user/InnopolisU
# 6616 distinct word(s) so far
# https://apply.innopolis.ru/en/
# 8234 distinct word(s) so far
# Error processing mailto:319@innopolis.ru: No connection adapters were found for 'mailto:319@innopolis.ru'
# https://panoroo.com/virtual-tours/NvQZM6B2
# 8234 distinct word(s) so far
# https://media.innopolis.university/en/news/
# 8234 distinct word(s) so far
# https://media.innopolis.university/en/events/
# 8236 distinct word(s) so far
# Error processing http://www.minsvyaz.ru/en/: HTTPConnectionPool(host='www.minsvyaz.ru', port=80): Max retries exceeded with url: /en/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa88e330370>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# https://minobrnauki.gov.ru/
# 8462 distinct word(s) so far
# https://career.innopolis.university/konkursnyezayavkiprofessorskoprepodavatelskogosostava/
# 8561 distinct word(s) so far
# https://apply.innopolis.university/
# 8561 distinct word(s) so far
# https://innopolis.university/proekty/activity/
# 8642 distinct word(s) so far
# https://media.innopolis.university/
# 8700 distinct word(s) so far
# https://innopolis.university/about/
# 8930 distinct word(s) so far
# https://innopolis.university/board/
# 9010 distinct word(s) so far
# https://innopolis.university/team/
# 9011 distinct word(s) so far
# https://innopolis.university/team-structure/
# 9016 distinct word(s) so far
# https://innopolis.university/team-structure/education-academics/
# 9019 distinct word(s) so far
# https://innopolis.university/team-structure/techcenters/
# 9022 distinct word(s) so far
# https://innopolis.university/faculty/
# 9895 distinct word(s) so far
# https://career.innopolis.university
# 10241 distinct word(s) so far
# https://career.innopolis.university/job
# 11567 distinct word(s) so far
# https://career.innopolis.university/relocation/
# 11808 distinct word(s) so far
# https://innopolis.university/campus
# 11957 distinct word(s) so far
# https://innopolis.university/sveden/
# 11965 distinct word(s) so far
# Error processing http://iustore.innopolis.ru: http://iustore.innopolis.ru
# https://apply.innopolis.university/open-day/
# 12014 distinct word(s) so far
# https://apply.innopolis.university/grant/
# 12121 distinct word(s) so far
# https://apply.innopolis.university/olympiad-bonus/
# 12204 distinct word(s) so far
# https://apply.innopolis.university/faq/
# 12311 distinct word(s) so far
# https://innopolis.university/sveden/apply/
# 12417 distinct word(s) so far
# https://apply.innopolis.university/bachelor/
# 12589 distinct word(s) so far
# https://apply.innopolis.university/master/
# 12619 distinct word(s) so far
# https://apply.innopolis.university/postgraduate-study/
# 12652 distinct word(s) so far
# https://dovuz.innopolis.university/about/
# 12691 distinct word(s) so far
# https://dovuz.innopolis.university/ege
# 12780 distinct word(s) so far
# https://dovuz.innopolis.university/training/
# 12880 distinct word(s) so far
# https://dovuz.innopolis.university/regular/
# 12892 distinct word(s) so far
# https://dovuz.innopolis.university/olympics/
# 12937 distinct word(s) so far
# https://dovuz.innopolis.university/events/
# 12937 distinct word(s) so far
# Error processing http://progmatica.ru/?utm_source=site&utm_medium=main_ui: http://progmatica.ru/?utm_source=site&utm_medium=main_ui
# Error processing https://team-project.university.innopolis.ru/partnership: https://team-project.university.innopolis.ru/partnership
# https://innopolis.university/dpo-courses/
# 13519 distinct word(s) so far
# Error processing https://stc.innopolis.university/: https://stc.innopolis.university/
# https://corporate.innopolis.university/education/
# 13666 distinct word(s) so far
# Error processing https://edu.innopolis.university/ooc: https://edu.innopolis.university/ooc
# Error processing https://stc.innopolis.university/careerinit: https://stc.innopolis.university/careerinit
# https://innopolis.university/ooc/
# 15092 distinct word(s) so far
# https://innopolis.university/ido/
# 15150 distinct word(s) so far
# https://innopolis.university/ppcenter/
# 15287 distinct word(s) so far
# https://apply.innopolis.university/stazhirovki-i-trudoustrojstvo/
# 15434 distinct word(s) so far
# https://apply.innopolis.university/stud-life/
# 15494 distinct word(s) so far
# https://innopolis.university/research/
# 15803 distinct word(s) so far
# https://innopolis.university/team-structure/team-faculty/
# 15824 distinct word(s) so far
# https://innopolis.university/team-structure/team-faculty2/
# 15844 distinct word(s) so far
# https://innopolis.university/publikatsii
# 15872 distinct word(s) so far
# https://innopolis.university/international-relations-office/
# 15899 distinct word(s) so far
# https://innopolis.university/seminars/
# 15937 distinct word(s) so far
# https://innopolis.university/nir2022/
# 15937 distinct word(s) so far
# https://innopolis.university/portfel-proektov/
# 16212 distinct word(s) so far
# https://innopolis.university/center-ai3/
# 16290 distinct word(s) so far
# https://innopolis.university/center-blockchain/
# 16371 distinct word(s) so far
# https://innopolis.university/centergis/
# 16450 distinct word(s) so far
# https://innopolis.university/center-cybersecurity/
# 16510 distinct word(s) so far
# https://innopolis.university/center-oil/
# 16535 distinct word(s) so far
# https://innopolis.university/center-robotics/
# 16638 distinct word(s) so far
# https://innopolis.university/center-energy/
# 16670 distinct word(s) so far
# https://innopolis.university/proekty/consulting/
# 16785 distinct word(s) so far
# https://innopolis.university/startupstudio/
# 17108 distinct word(s) so far
# https://innopolis.university/technologytransfercenter
# 17282 distinct word(s) so far
# https://innopolis.university/engineering-school/
# 17405 distinct word(s) so far
# https://innopolis.university/organizatsiya-i-provedenie-meropriyatiy/
# 17547 distinct word(s) so far
# https://innopolis.university/sponsorship/
# 17580 distinct word(s) so far
# https://innopolis.university/contacts/
# 17590 distinct word(s) so far
# https://innopolis.university/?special=Y
# 17590 distinct word(s) so far
# https://career.innopolis.university/
# 17590 distinct word(s) so far
# https://apply.innopolis.ru/get-in/
# 17839 distinct word(s) so far
# https://media.innopolis.university/news/Advanced-Engineering-School-iu-report2022/
# 17870 distinct word(s) so far
# https://media.innopolis.university/news/Russian-Science-Day-2023/
# 18281 distinct word(s) so far
# https://media.innopolis.university/news/cdto-meet-iu/
# 18291 distinct word(s) so far
# https://media.innopolis.university/news/Chief-Digital-Transformation-Officer-iu-2023/
# 18298 distinct word(s) so far
# https://media.innopolis.university/news/free-IT-courses-for-schoolchildren-Code-of-the-Future-iu-2023/
# 18309 distinct word(s) so far
# https://media.innopolis.university/news/AI-in-Digital-Transformation-State-Management-course/
# 18323 distinct word(s) so far
# https://media.innopolis.university/news/avatar-iu/
# 18378 distinct word(s) so far
# Error processing mailto:university@innopolis.ru: No connection adapters were found for 'mailto:university@innopolis.ru'
# https://innopolis.university/form/
# 18471 distinct word(s) so far
# Error processing https://innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf: Only html documents are supported, got: pdf
# https://t.me/universityinnopolis?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18471 distinct word(s) so far
# https://vk.com/innopolisu?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18471 distinct word(s) so far
# https://www.youtube.com/user/InnopolisU?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18471 distinct word(s) so far
# https://apply.innopolis.university/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18471 distinct word(s) so far
# https://career.innopolis.university/job?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18471 distinct word(s) so far
# Error processing http://iustore.innopolis.ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit: http://iustore.innopolis.ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Error processing tel:+78432039253?lang=ru&id=12&site=s1&template=university24&landing_mode=edit: No connection adapters were found for 'tel:+78432039253?lang=ru&id=12&site=s1&template=university24&landing_mode=edit'
# Error processing mailto:university@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit: No connection adapters were found for 'mailto:university@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit'
# https://innopolis.university/bitrix/admin/landing_view.php?lang=ru&id=12&site=s1&template=university24&landing_mode=edit#landing151?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18491 distinct word(s) so far
# http://www.innopolis.com/city/how-to-get/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18610 distinct word(s) so far
# Error processing mailto:319@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit: No connection adapters were found for 'mailto:319@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit'
# https://panoroo.com/virtual-tours/NvQZM6B2?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18610 distinct word(s) so far
# Error processing mailto:pr@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit: No connection adapters were found for 'mailto:pr@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit'
# https://media.innopolis.university/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18610 distinct word(s) so far
# https://media.innopolis.university/events/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18668 distinct word(s) so far
# https://innopolis.university/sveden/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18668 distinct word(s) so far
# Error processing https://digital.gov.ru/ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit: https://digital.gov.ru/ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Error processing https://edu.gov.ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit: https://edu.gov.ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# https://minobrnauki.gov.ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18668 distinct word(s) so far
# https://innopolis.university/bitrix/admin/landing_view.php?lang=ru&id=12&site=s1&template=university24&landing_mode=edit#landing306?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18668 distinct word(s) so far
# Error processing https://innopolis.university/files/politicacookies.pdf?lang=ru&id=12&site=s1&template=university24&landing_mode=edit: Only html documents are supported, got: pdf
# https://www.minobrnauki.gov.ru/action/situational_center/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18688 distinct word(s) so far
# https://innopolis.university/antiterror/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# 18725 distinct word(s) so far
# Error processing https://apply.innopolis.university/proekty/activity/en": https://apply.innopolis.university/proekty/activity/en"
# https://apply.innopolis.university/en/?special=Y
# 18725 distinct word(s) so far
# https://apply.innopolis.ru/en/get-in/
# 18952 distinct word(s) so far
# https://apply.innopolis.university/en/faq/
# 18967 distinct word(s) so far
# https://apply.innopolis.university/en/#block5327
# 18967 distinct word(s) so far
# https://apply.innopolis.university/en/olympiad-bonus/
# 19012 distinct word(s) so far
# Error processing https://apply.innopolis.university/en/development2/: https://apply.innopolis.university/en/development2/
# Error processing https://apply.innopolis.university/en/razrabotka-bezopasnyh-sistem-i-setej/: https://apply.innopolis.university/en/razrabotka-bezopasnyh-sistem-i-setej/
# https://www.ets.org/s/cv/toefl/at-home/
# 19157 distinct word(s) so far
# http://nic.gov.ru/en/proc/nic/legalize
# 19231 distinct word(s) so far
# https://www.hcch.net/en/instruments/conventions/authorities1/?cid=41
# 19303 distinct word(s) so far
# https://drive.google.com/file/d/1iMGgOVLc27BkuJYIB7cyDaqdNCfJhAbb/view?usp=sharing
# 19303 distinct word(s) so far
# https://www.embassy-worldwide.com/country/russia/?__cf_chl_jschl_tk__=a94cd95afa1311b39144c68ade05bb4c404c36e0-1603284143-0-AdT5wLmOm0W3vCpGYOe8JBgEGI_UYrAl9mWAr7wF22c8uVpnkbbSHOvIwBv5Iye4w3P-miBYqs-aStGmVo93k7jYCS4NQJ4cBWodhvlIsetlsYyQkaTTq_1OvbDiIsbarbVcfHyi_KH0wJDIB4Z1JSPevDKQ6oR5rH2pop3jbhEktZbCT0kRVDrWxej3fichPVhNcCSMyJo5Z_HfpLkGjswRihnDmrFYGShrU_nM8GeNxsvd1lq4tor0CCi4CDY-BmwRNtNskMF1TZM7sHN7KiYYjvEUqpo8sdK-5_o9tJQx
# 19558 distinct word(s) so far
# https://apply.innopolis.ru/get-in/tests/
# 19558 distinct word(s) so far
# https://innopolis.university/en/campus/
# 19558 distinct word(s) so far
# https://innopolis.com/en/
# 19633 distinct word(s) so far
# Error processing mailto:admissions@innopolis.ru: No connection adapters were found for 'mailto:admissions@innopolis.ru'
# Error processing https://apply.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf: Only html documents are supported, got: pdf
# Error processing https://media.innopolis.university/proekty/activity/en: https://media.innopolis.university/proekty/activity/en
# https://innopolis.university/en
# 19633 distinct word(s) so far
# https://media.innopolis.university/en/events
# 19633 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=*
# 19633 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Industry
# 19681 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Research
# 19724 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Education
# 19757 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Students life
# 19800 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Global
# 19822 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Robotics
# 19822 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Blockchain
# 19822 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Cybersecurity
# 19822 distinct word(s) so far
# https://media.innopolis.university/en/news/researchers-of-innopolis-university-will-speak-at-the-15th-international-kes-conference-kes-idt-23/
# 19822 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-interstudents-eng/
# 19827 distinct word(s) so far
# https://media.innopolis.university/en/news/devops-summer-school/
# 19851 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-for-international-candidates-/
# 19851 distinct word(s) so far
# https://media.innopolis.university/en/news/registration-innopolis-open-2020/
# 19856 distinct word(s) so far
# https://media.innopolis.university/en/news/cyber-resilience-petrenko/
# 19884 distinct word(s) so far
# https://media.innopolis.university/en/news/innopolis-university-extends-international-application-deadline-/
# 19884 distinct word(s) so far
# https://media.innopolis.university/en/news/self-driven-school/
# 19891 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-for-international-candidates/
# 19894 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=2
# 19905 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=3
# 19907 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=38
# 19964 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=39
# 19989 distinct word(s) so far
# Error processing https://spec.innopolis.university/: https://spec.innopolis.university/
# https://www.youtube.com/channel/UCZNo9zTHZNZOW4fSFcCKh_A
# 19989 distinct word(s) so far
# Error processing https://media.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf: Only html documents are supported, got: pdf
# https://innopolis.university/lk/?special=Y
# 19989 distinct word(s) so far
# https://innopolis.university/en/lk/
# 19995 distinct word(s) so far
# https://mail.innopolis.ru/
# 19995 distinct word(s) so far
# https://portal.university.innopolis.ru
# 19997 distinct word(s) so far
# https://it.university.innopolis.ru/portal
# 20012 distinct word(s) so far
# https://my.university.innopolis.ru/
# 20013 distinct word(s) so far
# https://dovuz.innopolis.university/login/
# 20027 distinct word(s) so far
# Error processing mailto:it@innopolis.ru: No connection adapters were found for 'mailto:it@innopolis.ru'
# https://innopolis.university/en/about/?special=Y
# 20027 distinct word(s) so far
# https://corporate.innopolis.university/en/
# 20063 distinct word(s) so far
# https://robotics.innopolis.university/en/
# 20072 distinct word(s) so far
# Error processing https://innopolis.university/upload/iblock/c68/AR_2016.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/upload/iblock/26c/AR_2017.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/upload/iblock/59f/AR_2018.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/upload/iblock/0b2/AR_2019.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/upload/iblock/189/AR2020(3).pdf: Only html documents are supported, got: pdf
# https://innopolis.university/en/board/?special=Y
# 20072 distinct word(s) so far
# Error processing https://digital.gov.ru/ru/: https://digital.gov.ru/ru/
# Error processing mailto:office@digital.gov.ru: No connection adapters were found for 'mailto:office@digital.gov.ru'
# Error processing http://mzio.tatarstan.ru: http://mzio.tatarstan.ru
# Error processing mailto:mzio@tatar.ru: No connection adapters were found for 'mailto:mzio@tatar.ru'
# https://innopolis.university/en/team/?special=Y
# 20072 distinct word(s) so far
# https://innopolis.university/en/team-structure/?special=Y
# 20072 distinct word(s) so far
# https://innopolis.university/en/team-director/
# 20088 distinct word(s) so far
# https://innopolis.university/en/team-rector/
# 20095 distinct word(s) so far
# https://innopolis.university/en/team-structure/education-academics/?special=Y
# 20095 distinct word(s) so far
# https://innopolis.university/en/team-academicpolicy/
# 20111 distinct word(s) so far
# https://innopolis.university/en/team-structure/techcenters/?special=Y
# 20111 distinct word(s) so far
# https://innopolis.university/en/center-robotics/
# 20159 distinct word(s) so far
# https://innopolis.university/en/center-cybersecurity/
# 20221 distinct word(s) so far
# https://innopolis.university/en/centergis/
# 20245 distinct word(s) so far
# https://innopolis.university/en/center-blockchain/
# 20277 distinct word(s) so far
# https://innopolis.university/en/centerforartificialintelligence/
# 20298 distinct word(s) so far
# https://innopolis.university/en/center-oil/
# 20306 distinct word(s) so far
# https://innopolis.university/en/faculty/?special=Y
# 20306 distinct word(s) so far
# https://innopolis.university/en/professor/manuel-mazzara-/
# 20306 distinct word(s) so far
# https://innopolis.university/en/lab-software-service-engineering/
# 20377 distinct word(s) so far
# https://innopolis.university/en/professor/vladimir-ivanov-/
# 20377 distinct word(s) so far
# https://innopolis.university/en/lab-industrializing-software/
# 20407 distinct word(s) so far
# https://innopolis.university/en/professor/andrey-sadovykh-/
# 20407 distinct word(s) so far
# https://innopolis.university/en/professor/eugene-zuev-/
# 20407 distinct word(s) so far
# https://innopolis.university/en/lab-operating-systems/
# 20425 distinct word(s) so far
# https://innopolis.university/en/professor/nikolay-shilov-/
# 20425 distinct word(s) so far
# https://innopolis.university/en/professor/aleksander-klimchik-/
# 20425 distinct word(s) so far
# https://innopolis.university/en/professor/igor-gaponov-/
# 20425 distinct word(s) so far
# https://innopolis.university/en/lab-robotics/
# 20498 distinct word(s) so far
# https://innopolis.university/en/professor/mohammad-reza-bahrami-/
# 20498 distinct word(s) so far
# https://innopolis.university/en/lab-cyberphysical-systems/
# 20519 distinct word(s) so far
# https://innopolis.university/en/professor/artem-burmyakov-/
# 20519 distinct word(s) so far
# https://innopolis.university/en/professor/adil-khan-/
# 20519 distinct word(s) so far
# https://innopolis.university/en/mlkr/
# 20627 distinct word(s) so far
# https://innopolis.university/en/professor/sergey-gorodetskiy-/
# 20627 distinct word(s) so far
# https://innopolis.university/en/professor/yaroslav-kholodov-/
# 20627 distinct word(s) so far
# https://innopolis.university/en/lab-bioinformatics/
# 20661 distinct word(s) so far
# https://innopolis.university/en/professor/rabab-marouf-/
# 20661 distinct word(s) so far
# https://innopolis.university/en/professor/nikola-zlatanov/
# 20661 distinct word(s) so far
# https://innopolis.university/en/professor/shinnazar-seytnazarov/
# 20661 distinct word(s) so far
# Error processing https://innopolis.university/en/team-faculty/#block2653: https://innopolis.university/en/team-faculty/#block2653
# https://innopolis.university/en/professor/mirko-farina-/
# 20661 distinct word(s) so far
# Error processing https://mirkofarina.weebly.com/: HTTPSConnectionPool(host='mirkofarina.weebly.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa88d956bf0>, 'Connection to mirkofarina.weebly.com timed out. (connect timeout=5)'))
# https://innopolis.university/en/lab-human/
# 20711 distinct word(s) so far
# https://innopolis.university/en/professor/artur-karimov-/
# 20711 distinct word(s) so far
# https://innopolis.university/en/professor/alena-protasova-/
# 20711 distinct word(s) so far
# https://innopolis.university/en/professor/ruslan-saduov-/
# 20711 distinct word(s) so far
# https://innopolis.university/en/professor/sergey-kladko-/
# 20711 distinct word(s) so far
# https://innopolis.university/en/professor/sergey-savin-/
# 20721 distinct word(s) so far
# Error processing http://www.researchgate.net/profile/Sergei_Savin2: http://www.researchgate.net/profile/Sergei_Savin2
# http://orcid.org/0000-0001-7954-3144
# 20722 distinct word(s) so far
# Error processing http://www.scopus.com/authid/detail.uri?authorId=55978984900: http://www.scopus.com/authid/detail.uri?authorId=55978984900
# Error processing http://scholar.google.ru/citations?user=sVjTfqEAAAAJ&hl=en: http://scholar.google.ru/citations?user=sVjTfqEAAAAJ&hl=en
# https://innopolis.university/en/professor/stanislav-protasov-/
# 20722 distinct word(s) so far
# https://innopolis.university/en/professor/aleksandr--naumchev/
# 20722 distinct word(s) so far
# Error processing mailto:a.naumchev@innopolis.ru: No connection adapters were found for 'mailto:a.naumchev@innopolis.ru'
# https://dblp.uni-trier.de/pers/hd/n/Naumchev:Alexandr
# 21177 distinct word(s) so far
# https://publons.com/researcher/1472116/alexandr-naumchev/
# 21216 distinct word(s) so far
# Error processing https://www.scopus.com/authid/detail.uri?authorId=57190306849: https://www.scopus.com/authid/detail.uri?authorId=57190306849
# https://innopolis.university/en/professor/artem-kruglov-/
# 21216 distinct word(s) so far
# https://innopolis.university/en/professor/georgiy-gelvanovskiy-/
# 21216 distinct word(s) so far
# https://innopolis.university/en/professor/ivan-konyukhov-/
# 21216 distinct word(s) so far
# https://innopolis.university/en/lab-oil-gas/
# 21252 distinct word(s) so far
# https://innopolis.university/en/professor/paolo-ciancarini-/
# 21252 distinct word(s) so far
# https://innopolis.university/en/professor/leon-derczynski-/
# 21252 distinct word(s) so far
# https://innopolis.university/en/professor/sebastian-denef-/
# 21252 distinct word(s) so far
# https://innopolis.university/en/professor/mohamad-kassab-/
# 21252 distinct word(s) so far
# https://innopolis.university/en/professor/tatyana-samsonova-/
# 21252 distinct word(s) so far
# Error processing http://www.campuslife.innopolis.ru/main: http://www.campuslife.innopolis.ru/main
# Error processing https://career.innopolis.university/proekty/activity/en: https://career.innopolis.university/proekty/activity/en
# https://career.innopolis.university/en/relocation
# 21322 distinct word(s) so far
# https://career.innopolis.university/en/job
# 21322 distinct word(s) so far
# https://career.innopolis.university/en/#460
# 21322 distinct word(s) so far
# https://career.innopolis.university/job/
# 21322 distinct word(s) so far
# Error processing https://carrer.innopolis.university: HTTPSConnectionPool(host='carrer.innopolis.university', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa88f045f60>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error processing https://career.innopolis.university/en/job/?section_id=*: 'NoneType' object has no attribute 'text'
# Error processing https://career.innopolis.university/en/job/?section_id=30251: 'NoneType' object has no attribute 'text'
# https://career.innopolis.university/en/job/#career-feedback__resume-form
# 21322 distinct word(s) so far
# Error processing https://career.innopolis.university/upload/Personal_data_policy_RU_EN.pdf: Only html documents are supported, got: pdf
# Error processing mailto:faculty@innopolis.ru: No connection adapters were found for 'mailto:faculty@innopolis.ru'
# Error processing https://career.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf: Only html documents are supported, got: pdf
# https://career.innopolis.university/en/relocation/
# 21322 distinct word(s) so far
# Error processing mailto:resume@innopolis.ru: No connection adapters were found for 'mailto:resume@innopolis.ru'
# https://innopolis.university/en/campus?special=Y
# 21322 distinct word(s) so far
# http://hotel.innopolis.university/
# 21417 distinct word(s) so far
# https://innopolis.university/en/contacts/?special=Y
# 21417 distinct word(s) so far
# Error processing tel:+78432039253: No connection adapters were found for 'tel:+78432039253'
# Error processing mailto:corporate@innopolis.university: No connection adapters were found for 'mailto:corporate@innopolis.university'
# Error processing mailto:dovuz@innopolis.university: No connection adapters were found for 'mailto:dovuz@innopolis.university'
# Error processing mailto:pr@innopolis.ru: No connection adapters were found for 'mailto:pr@innopolis.ru'
# Error processing mailto:student.affairs.dep@innopolis.ru: No connection adapters were found for 'mailto:student.affairs.dep@innopolis.ru'
# https://t.me/StudentAffairs_bot
# 21419 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/?special=Y
# 21419 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/CE/
# 21425 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/DS-AI/
# 21432 distinct word(s) so far
# Error processing https://apply.innopolis.university/en/bachelor/null: https://apply.innopolis.university/en/bachelor/null
# Error processing https://innopolis.university/filespublic/2022ProfTestMath.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/filespublic/2022ProfTestInf.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/filespublic/2022%20English.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/filespublic/contest-31323-ru.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/filespublic/Overview%20of%20the%20BS%20Program1.pdf: Only html documents are supported, got: pdf
# https://apply.innopolis.ru/en/get-in/tests/
# 21432 distinct word(s) so far
# https://apply.innopolis.university/en/master/?special=Y
# 21432 distinct word(s) so far
# https://apply.innopolis.university/en/grant/
# 21449 distinct word(s) so far
# https://apply.innopolis.university/en/master/development/
# 21505 distinct word(s) so far
# https://apply.innopolis.university/en/master/securityandnetworkengineering/
# 21534 distinct word(s) so far
# https://apply.innopolis.university/en/master/datascience/
# 21570 distinct word(s) so far
# https://apply.innopolis.university/en/master/robotics/
# 21598 distinct word(s) so far
# https://apply.innopolis.university/en/master/technological-entrepreneurship/
# 21684 distinct word(s) so far
# https://apply.innopolis.university/en/postgraduate-study/?special=Y
# 21684 distinct word(s) so far
# Error processing https://scholar.google.com/citations?hl=en&user=NMrHhLwAAAAJ: https://scholar.google.com/citations?hl=en&user=NMrHhLwAAAAJ
# Error processing https://scholar.google.com/citations?user=zMTV1PYAAAAJ&hl=en&oi=ao: https://scholar.google.com/citations?user=zMTV1PYAAAAJ&hl=en&oi=ao
# Error processing https://scholar.google.com/citations?user=bsy2_u0AAAAJ&hl=en&oi=ao: https://scholar.google.com/citations?user=bsy2_u0AAAAJ&hl=en&oi=ao
# Error processing https://scholar.google.com/citations?hl=en&user=KLpMBj0AAAAJ: https://scholar.google.com/citations?hl=en&user=KLpMBj0AAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=1h9WcVQAAAAJ: https://scholar.google.com/citations?hl=en&user=1h9WcVQAAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=Z0Z96RsAAAAJ: https://scholar.google.com/citations?hl=en&user=Z0Z96RsAAAAJ
# Error processing https://scholar.google.com/citations?user=PdMO57sAAAAJ&hl=en: https://scholar.google.com/citations?user=PdMO57sAAAAJ&hl=en
# Error processing https://scholar.google.com/citations?hl=en&user=WD0VCdkAAAAJ: https://scholar.google.com/citations?hl=en&user=WD0VCdkAAAAJ
# Error processing https://scholar.google.com/citations?user=rbl2ou8AAAAJ&hl=en&oi=ao: https://scholar.google.com/citations?user=rbl2ou8AAAAJ&hl=en&oi=ao
# Error processing https://scholar.google.com/citations?hl=en&user=si3p_GUAAAAJ: https://scholar.google.com/citations?hl=en&user=si3p_GUAAAAJ
# Error processing https://scholar.google.com/citations?user=9O52hrYAAAAJ&hl=en&oi=ao: https://scholar.google.com/citations?user=9O52hrYAAAAJ&hl=en&oi=ao
# Error processing https://scholar.google.com/citations?user=d7so04UAAAAJ&hl=en&oi=ao: https://scholar.google.com/citations?user=d7so04UAAAAJ&hl=en&oi=ao
# Error processing https://scholar.google.com/citations?hl=en&user=th6g2bgAAAAJ: https://scholar.google.com/citations?hl=en&user=th6g2bgAAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=tTd5DEAAAAAJ: https://scholar.google.com/citations?hl=en&user=tTd5DEAAAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=kEHqrCcAAAAJ: https://scholar.google.com/citations?hl=en&user=kEHqrCcAAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=ngwd2ScAAAAJ: https://scholar.google.com/citations?hl=en&user=ngwd2ScAAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=sVjTfqEAAAAJ: https://scholar.google.com/citations?hl=en&user=sVjTfqEAAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=pDske8oAAAAJ: https://scholar.google.com/citations?hl=en&user=pDske8oAAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=16AyxX0AAAAJ: https://scholar.google.com/citations?hl=en&user=16AyxX0AAAAJ
# Error processing https://scholar.google.com/citations?hl=en&user=cF_2ys0AAAAJ: https://scholar.google.com/citations?hl=en&user=cF_2ys0AAAAJ
# Error processing https://apply.innopolis.university/en/postgraduate-study/admissions@innopolis.ru: https://apply.innopolis.university/en/postgraduate-study/admissions@innopolis.ru
# https://apply.innopolis.university/en/stud-life/?special=Y
# 21684 distinct word(s) so far
# Error processing http://www.campuslife.innopolis.ru/events: http://www.campuslife.innopolis.ru/events
# Error processing http://www.campuslife.innopolis.ru/clubs: http://www.campuslife.innopolis.ru/clubs
# Error processing http://www.campuslife.innopolis.ru/innopoints: http://www.campuslife.innopolis.ru/innopoints
# https://innopolis.university/en/international-relations-office
# 21684 distinct word(s) so far
# http://innopolis.ru/
# 21723 distinct word(s) so far
# https://innopolis.university/en/international-relations-office/?special=Y
# 21723 distinct word(s) so far
# Error processing mailto:international@innopolis.university: No connection adapters were found for 'mailto:international@innopolis.university'
# https://innopolis.university/success-stories/andrey-palaev/
# 21737 distinct word(s) so far
# https://innopolis.university/success-stories/abdelrahman-abounegm/
# 21737 distinct word(s) so far
# https://innopolis.university/success-stories/ananga-thapaliya/
# 21737 distinct word(s) so far
# https://innopolis.university/success-stories/kerim-kochekov/
# 21737 distinct word(s) so far
# https://innopolis.university/success-stories/maksim-korsunov/
# 21737 distinct word(s) so far
# https://innopolis.university/success-stories/marina-ivanova/
# 21737 distinct word(s) so far
# https://innopolis.university/success-stories/semen-kiselev/
# 21737 distinct word(s) so far
# https://media.innopolis.university/news/researchers-of-innopolis-university-will-speak-at-the-15th-international-kes-conference-kes-idt-23/
# 21751 distinct word(s) so far
# https://innopolis.university/en/incomingstudents/?special=Y
# 21751 distinct word(s) so far
# Error processing https://innopolis.university/incomingstudents/: https://innopolis.university/incomingstudents/
# https://innopolis.university/en/incomingstudents/#block5171
# 21751 distinct word(s) so far
# https://innopolis.university/success-stories/eduardo-fernandes/
# 21751 distinct word(s) so far
# https://innopolis.university/success-stories/zhakubayev-azat/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/bekhruz-nutfilloyev/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/shokhrukhbek-yursunjonov/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/del-yan/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/nils-becker/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/ramazan-bolat/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/yaroslav-mustafin/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/bakhtiyar-bauyrzhan/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/dastan-makhutov/
# 21752 distinct word(s) so far
# https://innopolis.university/success-stories/rafael-toizhanov/
# 21752 distinct word(s) so far
# https://innopolis.university/en/outgoingstudents/?special=Y
# 21752 distinct word(s) so far
# Error processing https://innopolis.university/outgoingstudents/: https://innopolis.university/outgoingstudents/
# https://innopolis.university/en/outgoingstudents/#block5177
# 21752 distinct word(s) so far
# https://innopolis.university/en/outgoingstudents/#b6462
# 21752 distinct word(s) so far
# https://summerschool.spbstu.ru/schools/winter_school/
# 21918 distinct word(s) so far
# https://summerschool.spbstu.ru/schools/summer_school/
# 22003 distinct word(s) so far
# https://summerschool.spbstu.ru/visa_procedure/
# 22057 distinct word(s) so far
# https://www.uniroma1.it/en/pagina/summer-winter-school
# 22202 distinct word(s) so far
# https://www.uniroma1.it/en/pagina/summer-and-winter-schools
# 22357 distinct word(s) so far
# Error processing https://international.unitn.it/incoming/summer-and-winter-schools: https://international.unitn.it/incoming/summer-and-winter-schools
# https://www.unibo.it/en/teaching/summer-and-winter-schools
# 22438 distinct word(s) so far
# https://www.unibo.it/en/teaching/summer-and-winter-schools/2022
# 22528 distinct word(s) so far
# https://isc.bit.edu.cn/admissionsaid/spss/BITWinterPrograms_20201010031116496880/index.htm
# 22592 distinct word(s) so far
# https://drive.google.com/file/d/1KTQDBPsIkzroXMjZ7BMJ2oBtKPy5R2XL/view
# 22592 distinct word(s) so far
# Error processing https://econ.fudan.edu.cn/info/1530/19205.htm: HTTPSConnectionPool(host='econ.fudan.edu.cn', port=443): Max retries exceeded with url: /info/1530/19205.htm (Caused by SSLError(SSLError(1, '[SSL: UNSAFE_LEGACY_RENEGOTIATION_DISABLED] unsafe legacy renegotiation disabled (_ssl.c:997)')))
# Error processing https://econ.fudan.edu.cn/en/: HTTPSConnectionPool(host='econ.fudan.edu.cn', port=443): Max retries exceeded with url: /en/ (Caused by SSLError(SSLError(1, '[SSL: UNSAFE_LEGACY_RENEGOTIATION_DISABLED] unsafe legacy renegotiation disabled (_ssl.c:997)')))
# http://sie.uibe.edu.cn/en/xmjs/xfxm/90986.htm
# 22647 distinct word(s) so far
# https://drive.google.com/drive/folders/1fGUAB2641iCcxZAKK15RD3evyxVWQ0PE
# 22663 distinct word(s) so far
# Error processing https://hanyangwinter.com/: https://hanyangwinter.com/
# Error processing https://hanyangwinter.com/courses/: https://hanyangwinter.com/courses/
# https://winter.korea.ac.kr/src/main/main.php
# 22707 distinct word(s) so far
# https://winter.korea.ac.kr/src/program/session1.php
# 22834 distinct word(s) so far
# https://winter.korea.ac.kr/src/program/scholarship.php
# 22851 distinct word(s) so far
# https://winter.yonsei.ac.kr/main/default.asp
# 22883 distinct word(s) so far
# https://winter.yonsei.ac.kr/main/course.asp?mid=m02_02
# 22980 distinct word(s) so far
# https://winter.yonsei.ac.kr/main/contents.asp?mid=m03_05
# 22997 distinct word(s) so far
# Error processing https://oiasystem.ntu.edu.tw/summer/course/index.course/season/5: https://oiasystem.ntu.edu.tw/summer/course/index.course/season/5
# Error processing https://www.bsuir.by/m/12_100229_0_144670.pdf: Only html documents are supported, got: pdf
# https://english.spbstu.ru/education/programs/short-term-programs/summer-school/
# 23243 distinct word(s) so far
# Error processing https://english.spbstu.ru/upload/inter/brochure/flyer_Summer_School_eng_A4_2021.pdf: Only html documents are supported, got: pdf
# https://gsem.urfu.ru/en/prospective-students/short-term-programmes/international-summer-school/
# 23585 distinct word(s) so far
# Error processing https://www.uibk.ac.at/geographie/summerschool/2022/: https://www.uibk.ac.at/geographie/summerschool/2022/
# https://www.lut.fi/en/studies/lut-summer-school
# 23725 distinct word(s) so far
# https://www.lut.fi/en/studies/lut-summer-school/course-contents
# 24041 distinct word(s) so far
# https://www.grenoble-inp.fr/en/academics/grenoble-international-smart-engineering-summer-school-ginsen-2
# 24103 distinct word(s) so far
# https://drive.google.com/file/d/1s7WGLN_aaAqWelXf3zQ9PNacXc3UzCv_/view
# 24103 distinct word(s) so far
# https://drive.google.com/file/d/1ZpolTyO0vxWYhSiyjeW0zaI3fOrqdpsC/view
# 24103 distinct word(s) so far
# Error processing https://www.academiccourses.com/ESME-and-Epitech-Summer-School-in-Robotics-2022/France/ESME/: https://www.academiccourses.com/ESME-and-Epitech-Summer-School-in-Robotics-2022/France/ESME/
# https://www.estp.fr/summer-school-artificial-intelligence-sustainable-smart-cities
# 24340 distinct word(s) so far
# Error processing https://www.estp.fr/sites/default/files/2020-01/Summer%20School%20EPF%20ESTP%20Paris%202020.pdf: Only html documents are supported, got: pdf
# https://international-programs.cytech.cyu.fr/summer-school-visual-computing-artificial-intelligence-in-pau-or-cergy-pontoise/?_sp=1f16dc0f-a59f-4279-8019-455e265a15a8.1654264537501
# 24457 distinct word(s) so far
# https://www.uniroma1.it/en/pagina/sapienza-summer-schools
# 24462 distinct word(s) so far
# Error processing http://people.disim.univaq.it/~antonio.cicone/NoSAG21/NoSAG21_homepage.html: HTTPConnectionPool(host='people.disim.univaq.it', port=80): Max retries exceeded with url: /~antonio.cicone/NoSAG21/NoSAG21_homepage.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7fa88df69d80>, 'Connection to people.disim.univaq.it timed out. (connect timeout=5)'))
# Error processing http://people.disim.univaq.it/~antonio.cicone/NoSAG21/Program.html: HTTPConnectionPool(host='people.disim.univaq.it', port=80): Max retries exceeded with url: /~antonio.cicone/NoSAG21/Program.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7fa88df6a620>, 'Connection to people.disim.univaq.it timed out. (connect timeout=5)'))
# Error processing https://www.gssi.it/communication/news-events/item/16944-registrations-open-for-gssi-sif-summer-school-on-cosmic-rays: HTTPSConnectionPool(host='www.gssi.it', port=443): Max retries exceeded with url: /communication/news-events/item/16944-registrations-open-for-gssi-sif-summer-school-on-cosmic-rays (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))
# https://www.sif.it/corsi/scuola_fermi/mmxxii/208
# 24674 distinct word(s) so far
# Error processing https://www.gssi.it/communication/news-events/item/download/3458_b4b419b21b51b3b03d0bf5fff9d72970: HTTPSConnectionPool(host='www.gssi.it', port=443): Max retries exceeded with url: /communication/news-events/item/download/3458_b4b419b21b51b3b03d0bf5fff9d72970 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))
# Error processing https://www.aidlda.it/: https://www.aidlda.it/
# Error processing https://www.unipi.it/index.php/engineering: [Errno 2] No such file or directory: 'files/69249314c0c4b3942c969275da6917559f4fb58ebede2807fa929ef154a2a8d3ab48f64d179256eb7def5164b2af5a1c86267cd4b392024249a42abd035d3c6e.php/engineering'
# https://visum.inesctec.pt/
# 25251 distinct word(s) so far
# https://robotcraft.ingeniarius.pt/
# 25283 distinct word(s) so far
# https://robotcraft.ingeniarius.pt/programme
# 25331 distinct word(s) so far
# https://shortprogrammes.ef.uni-lj.si/programmes/ljubljana_summer_school/about/
# 25393 distinct word(s) so far
# https://shortprogrammes.ef.uni-lj.si/programmes/ljubljana_summer_school/courses_2022/
# 25393 distinct word(s) so far
# https://www.uab.cat/barcelona-summer-school/
# 25561 distinct word(s) so far
# https://www.uab.cat/web/courses/second-period-courses-1345844080922.html
# 25605 distinct word(s) so far
# https://climate.enveco.es/
# 25749 distinct word(s) so far
# https://www.upc.edu/en/other-courses/summer-courses
# 25777 distinct word(s) so far
# Error processing https://www.int.uzh.ch/en/in/shortprograms.html: HTTPSConnectionPool(host='www.int.uzh.ch', port=443): Max retries exceeded with url: /en/in/shortprograms.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fa88df317e0>, 'Connection to www.int.uzh.ch timed out. (connect timeout=5)'))
# https://summerschool.eitdigital.eu/#c40099
# 25858 distinct word(s) so far
# https://isc.bit.edu.cn/admissionsaid/spss/languageulture_20201010031104805795/index.htm
# 25910 distinct word(s) so far
# https://drive.google.com/file/d/1S1Vg-isJ69SVi6E8Irwdma8U0DG6bjio/view
# 25910 distinct word(s) so far
# Error processing https://econ.fudan.edu.cn/info/1530/19526.htm: HTTPSConnectionPool(host='econ.fudan.edu.cn', port=443): Max retries exceeded with url: /info/1530/19526.htm (Caused by SSLError(SSLError(1, '[SSL: UNSAFE_LEGACY_RENEGOTIATION_DISABLED] unsafe legacy renegotiation disabled (_ssl.c:997)')))
# https://drive.google.com/file/d/1Qrhj_1kSj_qHJD0mVU1VfhJmYOeGsC2N/view
# 25910 distinct word(s) so far
# http://sie.uibe.edu.cn/xmjs/xfxm/76260.htm
# 25965 distinct word(s) so far
# Error processing http://sie.uibe.edu.cn/docs/2022-01/e959439c597944d396e3e856bbf3d49c.pdf: Only html documents are supported, got: pdf
# https://drive.google.com/file/d/1-AgX_uxeI3aNU1iYQrQJR7NUYwSyfk2o/view
# 25965 distinct word(s) so far
# Error processing https://summerinstitute.hku.hk/special-announcement-page/: https://summerinstitute.hku.hk/special-announcement-page/
# ...
# 45240 distinct word(s) so far
# Error processing https://career.innopolis.university/proekty/activity/: https://career.innopolis.university/proekty/activity/
# https://career.innopolis.university/relocation
# 45240 distinct word(s) so far
# https://career.innopolis.university/#block57
# 45240 distinct word(s) so far
# https://career.innopolis.university/en/konkursnyezayavkiprofessorskoprepodavatelskogosostava/
# 45240 distinct word(s) so far
# Error processing https://career.innopolis.university/public/files/pps/PPS POL.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS PRIK.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/filespublic/%D0%BF%D1%80%D0%B8%D0%BA%D0%B0%D0%B7%20%D0%BE%D1%82%2008.12.2021%20%E2%84%96%20%D0%9E%D0%94_%D0%90%D0%94-01%20%D0%9E%20%D0%B2%D0%BD%D0%B5%D1%81%D0%B5%D0%BD%D0%B8%D0%B8%20%D0%B8%D0%B7%D0%BC%D0%B5%D0%BD%D0%B5%D0%BD%D0%B8%D0%B9%20%D0%B2%20%D0%9F%D0%BE%D0%BB%D0%BE%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%B9%20%D0%BA%D0%BE%D0%BC%D0%B8%D1%81%D1%81%D0%B8%D0%B8%20%D0%B8%20%D0%BF%D0%BE%D1%80%D1%8F%D0%B4%D0%BA%D0%B5%20%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%B0%20%D0%BD%D0%B0%20%D0%B7%D0%B0%D0%BC.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/filespublic/%D0%BF%D1%80%D0%B8%D0%BA%D0%B0%D0%B7%20%D0%BE%D1%82%2011.04.2021%20%E2%84%96%20%D0%9E%D0%94_%D0%90%D0%94-01%20%D0%9E%20%D0%B2%D0%BD%D0%B5%D1%81%D0%B5%D0%BD%D0%B8%D0%B8%20%D0%B8%D0%B7%D0%BC%D0%B5%D0%BD%D0%B5%D0%BD%D0%B8%D0%B9%20%D0%B2%20%D0%9F%D0%BE%D0%BB%D0%BE%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%B9%20%D0%BA%D0%BE%D0%BC%D0%B8%D1%81%D1%81%D0%B8%D0%B8%20%D0%B8%20%D0%BF%D0%BE%D1%80%D1%8F%D0%B4%D0%BA%D0%B5%20%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%B0%20%D0%BD%D0%B0%20%D0%B7%D0%B0%D0%BC.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/filespublic/%D0%BF%D1%80%D0%B8%D0%BA%D0%B0%D0%B7%20%D0%BE%D1%82%2001.02.2022%20%E2%84%96%20%D0%9E%D0%94_%D0%90%D0%94-22.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2015.12.10.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2016.01.26.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2016.02.26.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2016.03.30.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2016.04.29.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2016.05.27.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2016.07.01.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2016.07.28.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2016.10.28.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2017.02.09.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2017.03.06.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2017.04.11.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2017.05.05.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2017.06.29.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2017.07.20.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2017.10.27.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2017.11.30.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2018.03.30.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2018.05.30.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2018.07.27.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2018.08.29.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2018.10.16.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2018.12.19.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2018.12.30.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.01.17.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.02.12.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.04.12.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.05.30.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.06.20.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.07.19.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.09.12.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.10.25.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2019.11.14.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2020.04.27.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/pps/PPS 2020.05.21.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление_о_конкурсном_отборе_от_18_06_2020.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление о конкурсном отборе от 03.07.2020.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление_о_конкурсном_отборе_от_21_08_2020.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2018.09.2020.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление_о_конкурсном_отборе_от_15_10_2020.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление_о_конкурсном_отборе_от_29_12_2020.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2027.01.2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление_о_конкурсном_отборе_от_05_02_2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление_о_конкурсном_отборе_от_11_03_2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление_о_конкурсном_отборе_от_19_03_2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/объявление_о_конкурсном_отборе_от_08_04_2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BE_%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC_%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5_%D0%BE%D1%82_20_04_2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2030.04.2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2024.06.2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BE_%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC_%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5_%D0%BE%D1%82_22_07_2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BE_%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC_%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5_%D0%BE%D1%82_10_08_2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2017.09.2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BE_%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC_%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5_%D0%BE%D1%82_09_11_2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2011.11.2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2002.12.2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2030.12.2021.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2004.03.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2023.03.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2015.04.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2019.05.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2008.06.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2030.06.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2014.07.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BE_%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC_%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5_%D0%BE%D1%82_03_10_2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2030.09.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2013.10.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/files/%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BE%20%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%D0%BD%D0%BE%D0%BC%20%D0%BE%D1%82%D0%B1%D0%BE%D1%80%D0%B5%20%D0%BE%D1%82%2007.11.2022.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/public/files/pps/PPS%202022.07.12.pdf: Only html documents are supported, got: pdf
# Error processing https://innopolis.university/public/files/pps/PPS%20SPIS.pdf: Only html documents are supported, got: pdf
# Error processing https://career.innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf: Only html documents are supported, got: pdf
# Done
# [('и', 17400), ('the', 14951), ('в', 13195), ('and', 12973), ('of', 12332), ('in', 7541), ('to', 7077), ('на', 5984), ('university', 4937), ('по', 4785), ('с', 4741), ('a', 4500), ('for', 4368), ('иннополис', 3797), ('я', 3074), ('innopolis', 2876), ('для', 2707), ('университета', 2649), ('at', 2622), ('i', 2622)]
